# %%
import numpy as np
import matplotlib.pyplot as plt
#import math as m
#import pandas as pd
from scipy import constants as cn
#  https://docs.scipy.org/doc/scipy/reference/constants.html

# %%
# 1

def x_tr_t(ct,v,c):
    '''
    bt = v/c
    gm = 1/sqrt(1 - bt**2)
    ct' = gm*(ct - bt*x)
    x' = gm*(x - bt*ct)
    here:
    x'=0
    gm*(x - bt*ct) = 0
    '''
    bt = v/c
    x = bt*ct
    return x

# %%
# 2

def x_tr_x(ct,v,c):
    '''
    bt = v/c
    gm = 1/sqrt(1 - bt**2)
    ct' = gm*(ct - bt*x)
    x' = gm*(x - bt*ct)
    here:
    t'=0
    gm*(ct - bt*x) = 0
    '''
    bt = v/c
    x = ct/bt
    return x

# %%
# 3

# Set up an array of independent variables t that spans -100 to 100 seconds
t = np.linspace(0, 200, num=201, endpoint=True) - 100

# Make a figure
fig, ax = plt.subplots(figsize=(7,7))

# YOUR CODE HERE: Use ax.plot() to plot the t' and x' axes below
xt = x_tr_t(t*cn.c,0.2*cn.c,cn.c)
xx = x_tr_x(t*cn.c,0.2*cn.c,cn.c)
ax.plot(t*cn.c,xt, color='r')
ax.plot(t*cn.c,xx, color='r')

# Move the left and bottom "spines" (borders of the plot) to the center
# This makes a math textbook-like set of (x,t) axes instead of a box around the plot
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))

# Take out the top and right spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Make the two axes have the same scale
ax.set_aspect('equal')

# Set the axes ranges
ax.set_xlim([-1e10, 1e10])
ax.set_ylim([-1e10, 1e10])

# YOUR CODE HERE: Use ax.text() to add RED labels to the t' and x' axes below
ax.text(1e10,x_tr_t(1e10,0.2*cn.c,cn.c), "ct'", color='r')
ax.text(x_tr_t(1e10,0.2*cn.c,cn.c),1e10, "x'", color='r')

plt.show()

# %%
# 4

fig, ax = plt.subplots(figsize=(7,7))
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_aspect('equal')
ax.set_xlim([-1e10, 1e10])
ax.set_ylim([-1e10, 1e10])

bt = 0.25
c = 'r'
ax.plot(t*cn.c, x_tr_t(t*cn.c,bt*cn.c,cn.c) , color=c, label=f"v/c={bt}")
ax.plot(t*cn.c, x_tr_x(t*cn.c,bt*cn.c,cn.c), color=c)
ax.text(1e10,x_tr_t(1e10,bt*cn.c,cn.c), "ct'", color=c)
ax.text(x_tr_t(1e10,bt*cn.c,cn.c),1e10, "x'", color=c)

bt = 0.5
c = 'b'
ax.plot(t*cn.c, x_tr_t(t*cn.c,bt*cn.c,cn.c) , color=c, label=f"v/c={bt}")
ax.plot(t*cn.c, x_tr_x(t*cn.c,bt*cn.c,cn.c), color=c)
ax.text(1e10,x_tr_t(1e10,bt*cn.c,cn.c), "ct'", color=c)
ax.text(x_tr_t(1e10,bt*cn.c,cn.c),1e10, "x'", color=c)

bt = 0.75
c = 'g'
ax.plot(t*cn.c, x_tr_t(t*cn.c,bt*cn.c,cn.c) , color=c, label=f"v/c={bt}")
ax.plot(t*cn.c, x_tr_x(t*cn.c,bt*cn.c,cn.c), color=c)
ax.text(1e10,x_tr_t(1e10,bt*cn.c,cn.c), "ct'", color=c)
ax.text(x_tr_t(1e10,bt*cn.c,cn.c),1e10, "x'", color=c)

plt.legend()
plt.show()

# %%
# 5
'''
space-like curves is when cdt^2 - dx^2 < 0
light-like curves is when cdt^2 - dx^2 = 0
time-like curves is when cdt^2 - dx^2 > 0

t'-axes -> dx=0 -> cdt^2 - dx^2 > 0 -> time-like
x'-axes -> dt=0 -> cdt^2 - dx^2 < 0 -> space-like
limit (v=1) -> light-like
'''

fig, ax = plt.subplots(figsize=(7,7))
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_aspect('equal')
ax.set_xlim([-1e10, 1e10])
ax.set_ylim([-1e10, 1e10])

bt = 0.5
c = '0.7'
ax.plot(t*cn.c, x_tr_t(t*cn.c,bt*cn.c,cn.c) , color=c, label=f"v/c={bt}")
ax.plot(t*cn.c, x_tr_x(t*cn.c,bt*cn.c,cn.c), color=c)
ax.text(1e10,x_tr_t(1e10,bt*cn.c,cn.c), "ct'", color=c)
ax.text(x_tr_t(1e10,bt*cn.c,cn.c),1e10, "x'", color=c)

bt = 0.75
c = '0.55'
ax.plot(t*cn.c, x_tr_t(t*cn.c,bt*cn.c,cn.c) , color=c, label=f"v/c={bt}")
ax.plot(t*cn.c, x_tr_x(t*cn.c,bt*cn.c,cn.c), color=c)
ax.text(1e10,x_tr_t(1e10,bt*cn.c,cn.c), "ct'", color=c)
ax.text(x_tr_t(1e10,bt*cn.c,cn.c),1e10, "x'", color=c)

bt = 0.875
c = '0.4'
ax.plot(t*cn.c, x_tr_t(t*cn.c,bt*cn.c,cn.c) , color=c, label=f"v/c={bt}")
ax.plot(t*cn.c, x_tr_x(t*cn.c,bt*cn.c,cn.c), color=c)
ax.text(1e10,x_tr_t(1e10,bt*cn.c,cn.c), "ct'", color=c)
ax.text(x_tr_t(1e10,bt*cn.c,cn.c),1e10, "x'", color=c)

bt = 0.9375
c = '0.2'
ax.plot(t*cn.c, x_tr_t(t*cn.c,bt*cn.c,cn.c) , color=c, label=f"v/c={bt}")
ax.plot(t*cn.c, x_tr_x(t*cn.c,bt*cn.c,cn.c), color=c)
ax.text(1e10,x_tr_t(1e10,bt*cn.c,cn.c), "ct'", color=c)
ax.text(x_tr_t(1e10,bt*cn.c,cn.c),1e10, "x'", color=c)

bt = 0.9375
c = '0.0'
ax.plot(t*cn.c, x_tr_t(t*cn.c,cn.c,cn.c) , color=c, label=f"v/c=1")
#ax.text(1e10,x_tr_t(1e10,cn.c,cn.c), "c", color=c)

plt.legend()
plt.show()
